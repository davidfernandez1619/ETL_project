# %% [markdown]
# ## Cleaning our scrapped Oscar's CSV ##

# %%
import os

ruta_csv = os.path.abspath('nombre_del_archivo.csv')
print(ruta_csv)
# Out:
# /Users/davidusuariocasa/Desktop/Projects/ETL_project/nombre_del_archivo.csv

# %%
import pandas as pd


scrapped = pd.read_csv('/Users/davidusuariocasa/Desktop/Projects/ETL_project/Data/scrapped.csv'
)

# %%
scrapped = scrapped.dropna() # First, we remove all columns that contain at least one null value

scrapped = scrapped.reset_index() # Now we reset the indexes

# %%
scrapped
# Out:
#       index  year_film  year_ceremony  ceremony  \
# 0         0       1927           1928         1
# 1         2       1927           1928         1
# 2         3       1927           1928         1
# 3         4       1927           1928         1
# 4         5       1927           1928         1
# ...     ...        ...            ...       ...
# 1931   2144       2022           2023        95
# 1932   2145       2022           2023        95
# 1933   2146       2022           2023        95
# 1934   2147       2022           2023        95
# 1935   2148       2022           2023        95
#
#                            category  \
# 0                             ACTOR
# 1                     ART DIRECTION
# 2                    CINEMATOGRAPHY
# 3                    CINEMATOGRAPHY
# 4        DIRECTING (Comedy Picture)
# ...                             ...
# 1931                          SOUND
# 1932                 VISUAL EFFECTS
# 1933   WRITING (Adapted Screenplay)
# 1934  WRITING (Original Screenplay)
# 1935          AWARD OF COMMENDATION
#
#                                                    name  \
# 0                                         Emil Jannings
# 1                               William Cameron Menzies
# 2                                        Charles Rosher
# 3                                           Karl Struss
# 4                                       Lewis Milestone
# ...                                                 ...
# 1931  Mark Weingarten, James H. Mather, Al Nelson, C...
# 1932  Joe Letteri, Richard Baneham, Eric Saindon and...
# 1933                         Screenplay by Sarah Polley
# 1934          Written by Daniel Kwan & Daniel Scheinert
# 1935  To Ryan Laney for his innovative adaptation an...
#
#                                    film  duration     score
# 0                      The Last Command  1h 28min  8,0\n/10
# 1                             The Dove;  1h 30min  6,5\n/10
# 2                               Sunrise  1h 34min  8,1\n/10
# 3                               Sunrise  1h 34min  8,1\n/10
# 4                   Two Arabian Knights  1h 32min  6,7\n/10
# ...                                 ...       ...       ...
# 1931                  Top Gun: Maverick  2h 10min  8,3\n/10
# 1932           Avatar: The Way of Water  3h 12min  7,6\n/10
# 1933                      Women Talking  1h 44min  6,9\n/10
# 1934  Everything Everywhere All at Once  2h 19min  7,8\n/10
# 1935                Welcome to Chechnya  1h 47min  7,9\n/10
#
# [1936 rows x 9 columns]
