# %%
# Now to do our web scraping, we need to import all these libraries

import numpy as np 
from selenium import webdriver 
from webdriver_manager.chrome import ChromeDriverManager 
from selenium.webdriver.common.keys import Keys 
from selenium.webdriver.chrome.options import Options 
import time 
import random
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# %%
# I activate all these options for doing the web scrapping

opciones= Options()
opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
#para ocultarme como robot
opciones.add_experimental_option('useAutomationExtension', False)
opciones.add_argument('--start-maximized') 
opciones.add_argument('user.data-dir=selenium')
opciones.add_argument('--incognito')

# %%
import os

# Get the current working directory
current_directory = os.getcwd()

# Print the current working directory to know where my csv is
print(current_directory)
# Out:
# /Users/davidusuariocasa/Desktop/Projects/ETL_project

# %%
movies = pd.read_csv('/Users/davidusuariocasa/Desktop/Projects/ETL_project/CSVs/Oscars_cleaned.csv') # I open the csv with the CSV I want to iterate from 

movies.head(50)
# Out:
#     year_film  year_ceremony  ceremony                      category  \
# 0        1927           1928         1                         ACTOR
# 1        1927           1928         1                       ACTRESS
# 2        1927           1928         1                 ART DIRECTION
# 3        1927           1928         1                CINEMATOGRAPHY
# 4        1927           1928         1                CINEMATOGRAPHY
# 5        1927           1928         1    DIRECTING (Comedy Picture)
# 6        1927           1928         1  DIRECTING (Dramatic Picture)
# 7        1927           1928         1           ENGINEERING EFFECTS
# 8        1927           1928         1           OUTSTANDING PICTURE
# 9        1927           1928         1   UNIQUE AND ARTISTIC PICTURE
# 10       1927           1928         1          WRITING (Adaptation)
# 11       1927           1928         1      WRITING (Original Story)
# 12       1928           1929         2                         ACTOR
# 13       1928           1929         2                       ACTRESS
# 14       1928           1929         2                 ART DIRECTION
# 15       1928           1929         2                CINEMATOGRAPHY
# 16       1928           1929         2                     DIRECTING
# 17       1928           1929         2           OUTSTANDING PICTURE
# 18       1928           1929         2                       WRITING
# 19       1929           1930         3                         ACTOR
# 20       1929           1930         3                       ACTRESS
# 21       1929           1930         3                 ART DIRECTION
# 22       1929           1930         3                CINEMATOGRAPHY
# 23       1929           1930         3                     DIRECTING
# 24       1929           1930         3        OUTSTANDING PRODUCTION
# 25       1929           1930         3               SOUND RECORDING
# 26       1929           1930         3                       WRITING
# 27       1930           1931         4                         ACTOR
# 28       1930           1931         4                       ACTRESS
# 29       1930           1931         4                 ART DIRECTION
# 30       1930           1931         4                CINEMATOGRAPHY
# 31       1930           1931         4                     DIRECTING
# 32       1930           1931         4        OUTSTANDING PRODUCTION
# 33       1930           1931         4          WRITING (Adaptation)
# 34       1930           1931         4      WRITING (Original Story)
# 35       1931           1932         5                         ACTOR
# 36       1931           1932         5                         ACTOR
# 37       1931           1932         5                       ACTRESS
# 38       1931           1932         5                 ART DIRECTION
# 39       1931           1932         5                CINEMATOGRAPHY
# 40       1931           1932         5                     DIRECTING
# 41       1931           1932         5        OUTSTANDING PRODUCTION
# 42       1931           1932         5       SHORT SUBJECT (Cartoon)
# 43       1931           1932         5        SHORT SUBJECT (Comedy)
# 44       1931           1932         5       SHORT SUBJECT (Novelty)
# 45       1931           1932         5          WRITING (Adaptation)
# 46       1931           1932         5      WRITING (Original Story)
# 47       1932           1933         6                         ACTOR
# 48       1932           1933         6                       ACTRESS
# 49       1932           1933         6                 ART DIRECTION
#
#                                                  name  \
# 0                                       Emil Jannings
# 1                                        Janet Gaynor
# 2                             William Cameron Menzies
# 3                                      Charles Rosher
# 4                                         Karl Struss
# 5                                     Lewis Milestone
# 6                                       Frank Borzage
# 7                                         Roy Pomeroy
# 8                              Paramount Famous Lasky
# 9                                                 Fox
# 10                                    Benjamin Glazer
# 11                                          Ben Hecht
# 12                                      Warner Baxter
# 13                                      Mary Pickford
# 14                                     Cedric Gibbons
# 15                                     Clyde De Vinna
# 16                                        Frank Lloyd
# 17                                Metro-Goldwyn-Mayer
# 18                                         Hans Kraly
# 19                                      George Arliss
# 20                                      Norma Shearer
# 21                                       Herman Rosse
# 22             Joseph T. Rucker, Willard Van Der Veer
# 23                                    Lewis Milestone
# 24                                          Universal
# 25  Metro-Goldwyn-Mayer Studio Sound Department, D...
# 26                                     Frances Marion
# 27                                   Lionel Barrymore
# 28                                     Marie Dressler
# 29                                            Max Rée
# 30                                       Floyd Crosby
# 31                                      Norman Taurog
# 32                                          RKO Radio
# 33                                   Howard Estabrook
# 34                                 John Monk Saunders
# 35                                      Wallace Beery
# 36                                      Fredric March
# 37                                        Helen Hayes
# 38                                       Gordon Wiles
# 39                                         Lee Garmes
# 40                                      Frank Borzage
# 41                                Metro-Goldwyn-Mayer
# 42                              Walt Disney, Producer
# 43                                Hal Roach, Producer
# 44                             Mack Sennett, Producer
# 45                                        Edwin Burke
# 46                                     Frances Marion
# 47                                   Charles Laughton
# 48                                  Katharine Hepburn
# 49                                 William S. Darling
#
#                                film
# 0                  The Last Command
# 1                        7th Heaven
# 2                         The Dove;
# 3                           Sunrise
# 4                           Sunrise
# 5               Two Arabian Knights
# 6                        7th Heaven
# 7                             Wings
# 8                             Wings
# 9                           Sunrise
# 10                       7th Heaven
# 11                       Underworld
# 12                   In Old Arizona
# 13                         Coquette
# 14       The Bridge of San Luis Rey
# 15  White Shadows in the South Seas
# 16                  The Divine Lady
# 17              The Broadway Melody
# 18                      The Patriot
# 19                         Disraeli
# 20                     The Divorcee
# 21                     King of Jazz
# 22      With Byrd at the South Pole
# 23   All Quiet on the Western Front
# 24   All Quiet on the Western Front
# 25                    The Big House
# 26                    The Big House
# 27                      A Free Soul
# 28                     Min and Bill
# 29                         Cimarron
# 30                             Tabu
# 31                           Skippy
# 32                         Cimarron
# 33                         Cimarron
# 34                  The Dawn Patrol
# 35                        The Champ
# 36          Dr. Jekyll and Mr. Hyde
# 37       The Sin of Madelon Claudet
# 38                    Transatlantic
# 39                 Shanghai Express
# 40                         Bad Girl
# 41                      Grand Hotel
# 42                Flowers and Trees
# 43                    The Music Box
# 44              Wrestling Swordfish
# 45                         Bad Girl
# 46                        The Champ
# 47   The Private Life of Henry VIII
# 48                    Morning Glory
# 49                        Cavalcade

# %%
# Now, I'm going to iterate through my 'films' column and take the box office of each film from boxofficemojo.com if it exists. 
# But, if I iterate through all my rows, in my iteration number 50 aprox, Google asks me if I'm a bot and I can't iterate anymore
# Because of this, I'm going to iterate through groups of 45 rows, and save each iteration in a new CSV

df1 = movies[0:46]

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

movies['box_office'] = np.nan

driver = webdriver.Firefox()

for index, (value, year) in enumerate(zip(df1['film'], df1['year_film'])):
    driver.get("https://www.google.com/webhp?hl=es&sa=X&ved=0ahUKEwib6NqMzP7_AhUbVqQEHU22BKcQPAgJ")
    driver.implicitly_wait(2)

    try:
        driver.find_element("css selector", "#L2AGLb > div:nth-child(1)").click()  # We click to accept the cookies
    except:
        pass

    driver.find_element("css selector", "#APjFqb").send_keys(f'"{value} {str(year)}" site:https://www.boxofficemojo.com/', Keys.ENTER)  # We select the search box with each film and year

    try:
        driver.find_element("css selector", ".LC20lb").click()  # If we get results, we click on the link

        try:
            box_office = driver.find_element('css selector', '.mojo-performance-summary-table > div:nth-child(4) > span:nth-child(3) > span:nth-child(1)').text  # If the page shows the box office, we store the value in a variable called 'box_office'
            df1.loc[index, 'box_office'] = box_office

        except:
            df1.loc[index, 'box_office'] = np.nan  # If not, we store the value as null
    except:
        df1.loc[index, 'box_office'] = np.nan

driver.quit()

# %%
df1
# Out:
#     year_film  year_ceremony  ceremony                      category  \
# 0        1927           1928         1                         ACTOR
# 1        1927           1928         1                       ACTRESS
# 2        1927           1928         1                 ART DIRECTION
# 3        1927           1928         1                CINEMATOGRAPHY
# 4        1927           1928         1                CINEMATOGRAPHY
# 5        1927           1928         1    DIRECTING (Comedy Picture)
# 6        1927           1928         1  DIRECTING (Dramatic Picture)
# 7        1927           1928         1           ENGINEERING EFFECTS
# 8        1927           1928         1           OUTSTANDING PICTURE
# 9        1927           1928         1   UNIQUE AND ARTISTIC PICTURE
# 10       1927           1928         1          WRITING (Adaptation)
# 11       1927           1928         1      WRITING (Original Story)
# 12       1928           1929         2                         ACTOR
# 13       1928           1929         2                       ACTRESS
# 14       1928           1929         2                 ART DIRECTION
# 15       1928           1929         2                CINEMATOGRAPHY
# 16       1928           1929         2                     DIRECTING
# 17       1928           1929         2           OUTSTANDING PICTURE
# 18       1928           1929         2                       WRITING
# 19       1929           1930         3                         ACTOR
# 20       1929           1930         3                       ACTRESS
# 21       1929           1930         3                 ART DIRECTION
# 22       1929           1930         3                CINEMATOGRAPHY
# 23       1929           1930         3                     DIRECTING
# 24       1929           1930         3        OUTSTANDING PRODUCTION
# 25       1929           1930         3               SOUND RECORDING
# 26       1929           1930         3                       WRITING
# 27       1930           1931         4                         ACTOR
# 28       1930           1931         4                       ACTRESS
# 29       1930           1931         4                 ART DIRECTION
# 30       1930           1931         4                CINEMATOGRAPHY
# 31       1930           1931         4                     DIRECTING
# 32       1930           1931         4        OUTSTANDING PRODUCTION
# 33       1930           1931         4          WRITING (Adaptation)
# 34       1930           1931         4      WRITING (Original Story)
# 35       1931           1932         5                         ACTOR
# 36       1931           1932         5                         ACTOR
# 37       1931           1932         5                       ACTRESS
# 38       1931           1932         5                 ART DIRECTION
# 39       1931           1932         5                CINEMATOGRAPHY
# 40       1931           1932         5                     DIRECTING
# 41       1931           1932         5        OUTSTANDING PRODUCTION
# 42       1931           1932         5       SHORT SUBJECT (Cartoon)
# 43       1931           1932         5        SHORT SUBJECT (Comedy)
# 44       1931           1932         5       SHORT SUBJECT (Novelty)
# 45       1931           1932         5          WRITING (Adaptation)
#
#                                                  name  \
# 0                                       Emil Jannings
# 1                                        Janet Gaynor
# 2                             William Cameron Menzies
# 3                                      Charles Rosher
# 4                                         Karl Struss
# 5                                     Lewis Milestone
# 6                                       Frank Borzage
# 7                                         Roy Pomeroy
# 8                              Paramount Famous Lasky
# 9                                                 Fox
# 10                                    Benjamin Glazer
# 11                                          Ben Hecht
# 12                                      Warner Baxter
# 13                                      Mary Pickford
# 14                                     Cedric Gibbons
# 15                                     Clyde De Vinna
# 16                                        Frank Lloyd
# 17                                Metro-Goldwyn-Mayer
# 18                                         Hans Kraly
# 19                                      George Arliss
# 20                                      Norma Shearer
# 21                                       Herman Rosse
# 22             Joseph T. Rucker, Willard Van Der Veer
# 23                                    Lewis Milestone
# 24                                          Universal
# 25  Metro-Goldwyn-Mayer Studio Sound Department, D...
# 26                                     Frances Marion
# 27                                   Lionel Barrymore
# 28                                     Marie Dressler
# 29                                            Max Rée
# 30                                       Floyd Crosby
# 31                                      Norman Taurog
# 32                                          RKO Radio
# 33                                   Howard Estabrook
# 34                                 John Monk Saunders
# 35                                      Wallace Beery
# 36                                      Fredric March
# 37                                        Helen Hayes
# 38                                       Gordon Wiles
# 39                                         Lee Garmes
# 40                                      Frank Borzage
# 41                                Metro-Goldwyn-Mayer
# 42                              Walt Disney, Producer
# 43                                Hal Roach, Producer
# 44                             Mack Sennett, Producer
# 45                                        Edwin Burke
#
#                                film    box_office
# 0                  The Last Command           NaN
# 1                        7th Heaven           NaN
# 2                         The Dove;           NaN
# 3                           Sunrise      $121,107
# 4                           Sunrise      $121,107
# 5               Two Arabian Knights           NaN
# 6                        7th Heaven           NaN
# 7                             Wings          $746
# 8                             Wings          $746
# 9                           Sunrise      $121,107
# 10                       7th Heaven           NaN
# 11                       Underworld  $467,222,728
# 12                   In Old Arizona           NaN
# 13                         Coquette           NaN
# 14       The Bridge of San Luis Rey           NaN
# 15  White Shadows in the South Seas           NaN
# 16                  The Divine Lady           NaN
# 17              The Broadway Melody           NaN
# 18                      The Patriot           NaN
# 19                         Disraeli           NaN
# 20                     The Divorcee           NaN
# 21                     King of Jazz           NaN
# 22      With Byrd at the South Pole           NaN
# 23   All Quiet on the Western Front           NaN
# 24   All Quiet on the Western Front           NaN
# 25                    The Big House           NaN
# 26                    The Big House           NaN
# 27                      A Free Soul           NaN
# 28                     Min and Bill           NaN
# 29                         Cimarron           NaN
# 30                             Tabu           NaN
# 31                           Skippy           NaN
# 32                         Cimarron           NaN
# 33                         Cimarron           NaN
# 34                  The Dawn Patrol           NaN
# 35                        The Champ           NaN
# 36          Dr. Jekyll and Mr. Hyde       $16,615
# 37       The Sin of Madelon Claudet           NaN
# 38                    Transatlantic           NaN
# 39                 Shanghai Express           NaN
# 40                         Bad Girl           NaN
# 41                      Grand Hotel           NaN
# 42                Flowers and Trees           NaN
# 43                    The Music Box           NaN
# 44              Wrestling Swordfish           NaN
# 45                         Bad Girl           NaN

# %%
df2 = movies[46:91]
df2 = df2.reset_index()
df2.drop('index', axis=1)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

movies['box_office'] = np.nan

driver = webdriver.Firefox()

for index, (value, year) in enumerate(zip(df2['film'], df2['year_film'])):
    driver.get("https://www.google.com/webhp?hl=es&sa=X&ved=0ahUKEwib6NqMzP7_AhUbVqQEHU22BKcQPAgJ")
    driver.implicitly_wait(2)

    try:
        driver.find_element("css selector", "#L2AGLb > div:nth-child(1)").click()  # We click to accept the cookies
    except:
        pass

    driver.find_element("css selector", "#APjFqb").send_keys(f'"{value} {str(year)}" site:https://www.boxofficemojo.com/', Keys.ENTER)  # We select the search box with each film and year

    try:
        driver.find_element("css selector", ".LC20lb").click()  # If we get results, we click on the link

        try:
            box_office = driver.find_element('css selector', '.mojo-performance-summary-table > div:nth-child(4) > span:nth-child(3) > span:nth-child(1)').text  # If the page shows the box office, we store the value in a variable called 'box_office'
            df2.loc[index, 'box_office'] = box_office

        except:
            df2.loc[index, 'box_office'] = np.nan  # If not, we store the value as null
    except:
        df2.loc[index, 'box_office'] = np.nan

driver.quit()

# %%
df3 = movies[90:136]
df3 = df3.reset_index()
df3 = df3.drop('index', axis=1)
df3
# Out:
#     year_film  year_ceremony  ceremony                      category  \
# 0        1935           1936         8      WRITING (Original Story)
# 1        1935           1936         8          WRITING (Screenplay)
# 2        1936           1937         9                         ACTOR
# 3        1936           1937         9    ACTOR IN A SUPPORTING ROLE
# 4        1936           1937         9                       ACTRESS
# 5        1936           1937         9  ACTRESS IN A SUPPORTING ROLE
# 6        1936           1937         9                 ART DIRECTION
# 7        1936           1937         9            ASSISTANT DIRECTOR
# 8        1936           1937         9                CINEMATOGRAPHY
# 9        1936           1937         9               DANCE DIRECTION
# 10       1936           1937         9                     DIRECTING
# 11       1936           1937         9                  FILM EDITING
# 12       1936           1937         9               MUSIC (Scoring)
# 13       1936           1937         9                  MUSIC (Song)
# 14       1936           1937         9        OUTSTANDING PRODUCTION
# 15       1936           1937         9       SHORT SUBJECT (Cartoon)
# 16       1936           1937         9         SHORT SUBJECT (Color)
# 17       1936           1937         9      SHORT SUBJECT (One-reel)
# 18       1936           1937         9      SHORT SUBJECT (Two-reel)
# 19       1936           1937         9               SOUND RECORDING
# 20       1936           1937         9      WRITING (Original Story)
# 21       1936           1937         9          WRITING (Screenplay)
# 22       1937           1938        10                         ACTOR
# 23       1937           1938        10    ACTOR IN A SUPPORTING ROLE
# 24       1937           1938        10                       ACTRESS
# 25       1937           1938        10  ACTRESS IN A SUPPORTING ROLE
# 26       1937           1938        10                 ART DIRECTION
# 27       1937           1938        10            ASSISTANT DIRECTOR
# 28       1937           1938        10                CINEMATOGRAPHY
# 29       1937           1938        10               DANCE DIRECTION
# 30       1937           1938        10                     DIRECTING
# 31       1937           1938        10                  FILM EDITING
# 32       1937           1938        10               MUSIC (Scoring)
# 33       1937           1938        10                  MUSIC (Song)
# 34       1937           1938        10        OUTSTANDING PRODUCTION
# 35       1937           1938        10       SHORT SUBJECT (Cartoon)
# 36       1937           1938        10         SHORT SUBJECT (Color)
# 37       1937           1938        10      SHORT SUBJECT (One-reel)
# 38       1937           1938        10      SHORT SUBJECT (Two-reel)
# 39       1937           1938        10               SOUND RECORDING
# 40       1937           1938        10      WRITING (Original Story)
# 41       1937           1938        10          WRITING (Screenplay)
# 42       1938           1939        11                         ACTOR
# 43       1938           1939        11    ACTOR IN A SUPPORTING ROLE
# 44       1938           1939        11                       ACTRESS
# 45       1938           1939        11  ACTRESS IN A SUPPORTING ROLE
#
#                                                  name  \
# 0                        Ben Hecht, Charles MacArthur
# 1                                      Dudley Nichols
# 2                                           Paul Muni
# 3                                      Walter Brennan
# 4                                        Luise Rainer
# 5                                    Gale Sondergaard
# 6                                         Richard Day
# 7                                       Jack Sullivan
# 8                                      Gaetano Gaudio
# 9                                       Seymour Felix
# 10                                        Frank Capra
# 11                                       Ralph Dawson
# 12  Warner Bros. Studio Music Department, Leo Forb...
# 13     Music by Jerome Kern; Lyrics by Dorothy Fields
# 14                                Metro-Goldwyn-Mayer
# 15                              Walt Disney, Producer
# 16                                       Warner Bros.
# 17                                Hal Roach, Producer
# 18                                Metro-Goldwyn-Mayer
# 19  Metro-Goldwyn-Mayer Studio Sound Department, D...
# 20                   Pierre Collings, Sheridan Gibney
# 21                   Pierre Collings, Sheridan Gibney
# 22                                      Spencer Tracy
# 23                                 Joseph Schildkraut
# 24                                       Luise Rainer
# 25                                        Alice Brady
# 26                                    Stephen Goosson
# 27                                        Robert Webb
# 28                                        Karl Freund
# 29                                         Hermes Pan
# 30                                        Leo McCarey
# 31                         Gene Havlick, Gene Milford
# 32  Universal Studio Music Department, Charles Pre...
# 33                    Music and Lyrics by Harry Owens
# 34                                       Warner Bros.
# 35                              Walt Disney, Producer
# 36                               Pete Smith, Producer
# 37                                  Skibo Productions
# 38                                Metro-Goldwyn-Mayer
# 39  United Artists Studio Sound Department, Thomas...
# 40                  William A. Wellman, Robert Carson
# 41    Norman Reilly Raine, Heinz Herald, Geza Herczeg
# 42                                      Spencer Tracy
# 43                                     Walter Brennan
# 44                                        Bette Davis
# 45                                        Fay Bainter
#
#                                film  box_office
# 0                     The Scoundrel         NaN
# 1                      The Informer         NaN
# 2        The Story of Louis Pasteur         NaN
# 3                   Come and Get It         NaN
# 4                The Great Ziegfeld         NaN
# 5                   Anthony Adverse         NaN
# 6                         Dodsworth         NaN
# 7   The Charge of the Light Brigade         NaN
# 8                   Anthony Adverse         NaN
# 9                The Great Ziegfeld         NaN
# 10           Mr. Deeds Goes to Town         NaN
# 11                  Anthony Adverse         NaN
# 12                  Anthony Adverse         NaN
# 13                       Swing Time         NaN
# 14               The Great Ziegfeld         NaN
# 15               The Country Cousin         NaN
# 16                  Give Me Liberty         NaN
# 17               Bored of Education         NaN
# 18                  The Public Pays         NaN
# 19                    San Francisco         NaN
# 20       The Story of Louis Pasteur         NaN
# 21       The Story of Louis Pasteur         NaN
# 22              Captains Courageous         NaN
# 23           The Life of Emile Zola         NaN
# 24                   The Good Earth         NaN
# 25                   In Old Chicago         NaN
# 26                     Lost Horizon         NaN
# 27                   In Old Chicago         NaN
# 28                   The Good Earth         NaN
# 29             A Damsel in Distress         NaN
# 30                  The Awful Truth         NaN
# 31                     Lost Horizon         NaN
# 32       One Hundred Men and a Girl         NaN
# 33                  Waikiki Wedding         NaN
# 34           The Life of Emile Zola         NaN
# 35                     The Old Mill         NaN
# 36                     Penny Wisdom         NaN
# 37  The Private Life of the Gannets         NaN
# 38                    Torture Money         NaN
# 39                    The Hurricane         NaN
# 40                   A Star Is Born         NaN
# 41           The Life of Emile Zola         NaN
# 42                        Boys Town         NaN
# 43                         Kentucky         NaN
# 44                          Jezebel         NaN
# 45                          Jezebel         NaN

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

movies['box_office'] = np.nan

driver = webdriver.Firefox()

for index, (value, year) in enumerate(zip(df2['film'], df2['year_film'])):
    driver.get("https://www.google.com/webhp?hl=es&sa=X&ved=0ahUKEwib6NqMzP7_AhUbVqQEHU22BKcQPAgJ")
    driver.implicitly_wait(2)

    try:
        driver.find_element("css selector", "#L2AGLb > div:nth-child(1)").click()  # We click to accept the cookies
    except:
        pass

    driver.find_element("css selector", "#APjFqb").send_keys(f'"{value} {str(year)}" site:https://www.boxofficemojo.com/', Keys.ENTER)  # We select the search box with each film and year

    try:
        driver.find_element("css selector", ".LC20lb").click()  # If we get results, we click on the link

        try:
            box_office = driver.find_element('css selector', '.mojo-performance-summary-table > div:nth-child(4) > span:nth-child(3) > span:nth-child(1)').text  # If the page shows the box office, we store the value in a variable called 'box_office'
            df2.loc[index, 'box_office'] = box_office

        except:
            df2.loc[index, 'box_office'] = np.nan  # If not, we store the value as null
    except:
        df2.loc[index, 'box_office'] = np.nan

driver.quit()

# %%
df3 = movies[90:136]
df3 = df3.reset_index()
df3 = df3.drop('index', axis=1)
df3
# Out:
#     year_film  year_ceremony  ceremony                      category  \
# 0        1935           1936         8      WRITING (Original Story)
# 1        1935           1936         8          WRITING (Screenplay)
# 2        1936           1937         9                         ACTOR
# 3        1936           1937         9    ACTOR IN A SUPPORTING ROLE
# 4        1936           1937         9                       ACTRESS
# 5        1936           1937         9  ACTRESS IN A SUPPORTING ROLE
# 6        1936           1937         9                 ART DIRECTION
# 7        1936           1937         9            ASSISTANT DIRECTOR
# 8        1936           1937         9                CINEMATOGRAPHY
# 9        1936           1937         9               DANCE DIRECTION
# 10       1936           1937         9                     DIRECTING
# 11       1936           1937         9                  FILM EDITING
# 12       1936           1937         9               MUSIC (Scoring)
# 13       1936           1937         9                  MUSIC (Song)
# 14       1936           1937         9        OUTSTANDING PRODUCTION
# 15       1936           1937         9       SHORT SUBJECT (Cartoon)
# 16       1936           1937         9         SHORT SUBJECT (Color)
# 17       1936           1937         9      SHORT SUBJECT (One-reel)
# 18       1936           1937         9      SHORT SUBJECT (Two-reel)
# 19       1936           1937         9               SOUND RECORDING
# 20       1936           1937         9      WRITING (Original Story)
# 21       1936           1937         9          WRITING (Screenplay)
# 22       1937           1938        10                         ACTOR
# 23       1937           1938        10    ACTOR IN A SUPPORTING ROLE
# 24       1937           1938        10                       ACTRESS
# 25       1937           1938        10  ACTRESS IN A SUPPORTING ROLE
# 26       1937           1938        10                 ART DIRECTION
# 27       1937           1938        10            ASSISTANT DIRECTOR
# 28       1937           1938        10                CINEMATOGRAPHY
# 29       1937           1938        10               DANCE DIRECTION
# 30       1937           1938        10                     DIRECTING
# 31       1937           1938        10                  FILM EDITING
# 32       1937           1938        10               MUSIC (Scoring)
# 33       1937           1938        10                  MUSIC (Song)
# 34       1937           1938        10        OUTSTANDING PRODUCTION
# 35       1937           1938        10       SHORT SUBJECT (Cartoon)
# 36       1937           1938        10         SHORT SUBJECT (Color)
# 37       1937           1938        10      SHORT SUBJECT (One-reel)
# 38       1937           1938        10      SHORT SUBJECT (Two-reel)
# 39       1937           1938        10               SOUND RECORDING
# 40       1937           1938        10      WRITING (Original Story)
# 41       1937           1938        10          WRITING (Screenplay)
# 42       1938           1939        11                         ACTOR
# 43       1938           1939        11    ACTOR IN A SUPPORTING ROLE
# 44       1938           1939        11                       ACTRESS
# 45       1938           1939        11  ACTRESS IN A SUPPORTING ROLE
#
#                                                  name  \
# 0                        Ben Hecht, Charles MacArthur
# 1                                      Dudley Nichols
# 2                                           Paul Muni
# 3                                      Walter Brennan
# 4                                        Luise Rainer
# 5                                    Gale Sondergaard
# 6                                         Richard Day
# 7                                       Jack Sullivan
# 8                                      Gaetano Gaudio
# 9                                       Seymour Felix
# 10                                        Frank Capra
# 11                                       Ralph Dawson
# 12  Warner Bros. Studio Music Department, Leo Forb...
# 13     Music by Jerome Kern; Lyrics by Dorothy Fields
# 14                                Metro-Goldwyn-Mayer
# 15                              Walt Disney, Producer
# 16                                       Warner Bros.
# 17                                Hal Roach, Producer
# 18                                Metro-Goldwyn-Mayer
# 19  Metro-Goldwyn-Mayer Studio Sound Department, D...
# 20                   Pierre Collings, Sheridan Gibney
# 21                   Pierre Collings, Sheridan Gibney
# 22                                      Spencer Tracy
# 23                                 Joseph Schildkraut
# 24                                       Luise Rainer
# 25                                        Alice Brady
# 26                                    Stephen Goosson
# 27                                        Robert Webb
# 28                                        Karl Freund
# 29                                         Hermes Pan
# 30                                        Leo McCarey
# 31                         Gene Havlick, Gene Milford
# 32  Universal Studio Music Department, Charles Pre...
# 33                    Music and Lyrics by Harry Owens
# 34                                       Warner Bros.
# 35                              Walt Disney, Producer
# 36                               Pete Smith, Producer
# 37                                  Skibo Productions
# 38                                Metro-Goldwyn-Mayer
# 39  United Artists Studio Sound Department, Thomas...
# 40                  William A. Wellman, Robert Carson
# 41    Norman Reilly Raine, Heinz Herald, Geza Herczeg
# 42                                      Spencer Tracy
# 43                                     Walter Brennan
# 44                                        Bette Davis
# 45                                        Fay Bainter
#
#                                film  box_office
# 0                     The Scoundrel         NaN
# 1                      The Informer         NaN
# 2        The Story of Louis Pasteur         NaN
# 3                   Come and Get It         NaN
# 4                The Great Ziegfeld         NaN
# 5                   Anthony Adverse         NaN
# 6                         Dodsworth         NaN
# 7   The Charge of the Light Brigade         NaN
# 8                   Anthony Adverse         NaN
# 9                The Great Ziegfeld         NaN
# 10           Mr. Deeds Goes to Town         NaN
# 11                  Anthony Adverse         NaN
# 12                  Anthony Adverse         NaN
# 13                       Swing Time         NaN
# 14               The Great Ziegfeld         NaN
# 15               The Country Cousin         NaN
# 16                  Give Me Liberty         NaN
# 17               Bored of Education         NaN
# 18                  The Public Pays         NaN
# 19                    San Francisco         NaN
# 20       The Story of Louis Pasteur         NaN
# 21       The Story of Louis Pasteur         NaN
# 22              Captains Courageous         NaN
# 23           The Life of Emile Zola         NaN
# 24                   The Good Earth         NaN
# 25                   In Old Chicago         NaN
# 26                     Lost Horizon         NaN
# 27                   In Old Chicago         NaN
# 28                   The Good Earth         NaN
# 29             A Damsel in Distress         NaN
# 30                  The Awful Truth         NaN
# 31                     Lost Horizon         NaN
# 32       One Hundred Men and a Girl         NaN
# 33                  Waikiki Wedding         NaN
# 34           The Life of Emile Zola         NaN
# 35                     The Old Mill         NaN
# 36                     Penny Wisdom         NaN
# 37  The Private Life of the Gannets         NaN
# 38                    Torture Money         NaN
# 39                    The Hurricane         NaN
# 40                   A Star Is Born         NaN
# 41           The Life of Emile Zola         NaN
# 42                        Boys Town         NaN
# 43                         Kentucky         NaN
# 44                          Jezebel         NaN
# 45                          Jezebel         NaN

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

movies['box_office'] = np.nan

driver = webdriver.Firefox()

for index, (value, year) in enumerate(zip(df3['film'], df3['year_film'])):
    driver.get("https://www.google.com/webhp?hl=es&sa=X&ved=0ahUKEwib6NqMzP7_AhUbVqQEHU22BKcQPAgJ")
    driver.implicitly_wait(2)

    try:
        driver.find_element("css selector", "#L2AGLb > div:nth-child(1)").click()  # We click to accept the cookies
    except:
        pass

    driver.find_element("css selector", "#APjFqb").send_keys(f'"{value} {str(year)}" site:https://www.boxofficemojo.com/', Keys.ENTER)  # We select the search box with each film and year

    try:
        driver.find_element("css selector", ".LC20lb").click()  # If we get results, we click on the link

        try:
            box_office = driver.find_element('css selector', '.mojo-performance-summary-table > div:nth-child(4) > span:nth-child(3) > span:nth-child(1)').text  # If the page shows the box office, we store the value in a variable called 'box_office'
            df3.loc[index, 'box_office'] = box_office

        except:
            df3.loc[index, 'box_office'] = np.nan  # If not, we store the value as null
    except:
        df3.loc[index, 'box_office'] = np.nan

driver.quit()

# %%
df3
# Out:
#     year_film  year_ceremony  ceremony                      category  \
# 0        1935           1936         8      WRITING (Original Story)
# 1        1935           1936         8          WRITING (Screenplay)
# 2        1936           1937         9                         ACTOR
# 3        1936           1937         9    ACTOR IN A SUPPORTING ROLE
# 4        1936           1937         9                       ACTRESS
# 5        1936           1937         9  ACTRESS IN A SUPPORTING ROLE
# 6        1936           1937         9                 ART DIRECTION
# 7        1936           1937         9            ASSISTANT DIRECTOR
# 8        1936           1937         9                CINEMATOGRAPHY
# 9        1936           1937         9               DANCE DIRECTION
# 10       1936           1937         9                     DIRECTING
# 11       1936           1937         9                  FILM EDITING
# 12       1936           1937         9               MUSIC (Scoring)
# 13       1936           1937         9                  MUSIC (Song)
# 14       1936           1937         9        OUTSTANDING PRODUCTION
# 15       1936           1937         9       SHORT SUBJECT (Cartoon)
# 16       1936           1937         9         SHORT SUBJECT (Color)
# 17       1936           1937         9      SHORT SUBJECT (One-reel)
# 18       1936           1937         9      SHORT SUBJECT (Two-reel)
# 19       1936           1937         9               SOUND RECORDING
# 20       1936           1937         9      WRITING (Original Story)
# 21       1936           1937         9          WRITING (Screenplay)
# 22       1937           1938        10                         ACTOR
# 23       1937           1938        10    ACTOR IN A SUPPORTING ROLE
# 24       1937           1938        10                       ACTRESS
# 25       1937           1938        10  ACTRESS IN A SUPPORTING ROLE
# 26       1937           1938        10                 ART DIRECTION
# 27       1937           1938        10            ASSISTANT DIRECTOR
# 28       1937           1938        10                CINEMATOGRAPHY
# 29       1937           1938        10               DANCE DIRECTION
# 30       1937           1938        10                     DIRECTING
# 31       1937           1938        10                  FILM EDITING
# 32       1937           1938        10               MUSIC (Scoring)
# 33       1937           1938        10                  MUSIC (Song)
# 34       1937           1938        10        OUTSTANDING PRODUCTION
# 35       1937           1938        10       SHORT SUBJECT (Cartoon)
# 36       1937           1938        10         SHORT SUBJECT (Color)
# 37       1937           1938        10      SHORT SUBJECT (One-reel)
# 38       1937           1938        10      SHORT SUBJECT (Two-reel)
# 39       1937           1938        10               SOUND RECORDING
# 40       1937           1938        10      WRITING (Original Story)
# 41       1937           1938        10          WRITING (Screenplay)
# 42       1938           1939        11                         ACTOR
# 43       1938           1939        11    ACTOR IN A SUPPORTING ROLE
# 44       1938           1939        11                       ACTRESS
# 45       1938           1939        11  ACTRESS IN A SUPPORTING ROLE
#
#                                                  name  \
# 0                        Ben Hecht, Charles MacArthur
# 1                                      Dudley Nichols
# 2                                           Paul Muni
# 3                                      Walter Brennan
# 4                                        Luise Rainer
# 5                                    Gale Sondergaard
# 6                                         Richard Day
# 7                                       Jack Sullivan
# 8                                      Gaetano Gaudio
# 9                                       Seymour Felix
# 10                                        Frank Capra
# 11                                       Ralph Dawson
# 12  Warner Bros. Studio Music Department, Leo Forb...
# 13     Music by Jerome Kern; Lyrics by Dorothy Fields
# 14                                Metro-Goldwyn-Mayer
# 15                              Walt Disney, Producer
# 16                                       Warner Bros.
# 17                                Hal Roach, Producer
# 18                                Metro-Goldwyn-Mayer
# 19  Metro-Goldwyn-Mayer Studio Sound Department, D...
# 20                   Pierre Collings, Sheridan Gibney
# 21                   Pierre Collings, Sheridan Gibney
# 22                                      Spencer Tracy
# 23                                 Joseph Schildkraut
# 24                                       Luise Rainer
# 25                                        Alice Brady
# 26                                    Stephen Goosson
# 27                                        Robert Webb
# 28                                        Karl Freund
# 29                                         Hermes Pan
# 30                                        Leo McCarey
# 31                         Gene Havlick, Gene Milford
# 32  Universal Studio Music Department, Charles Pre...
# 33                    Music and Lyrics by Harry Owens
# 34                                       Warner Bros.
# 35                              Walt Disney, Producer
# 36                               Pete Smith, Producer
# 37                                  Skibo Productions
# 38                                Metro-Goldwyn-Mayer
# 39  United Artists Studio Sound Department, Thomas...
# 40                  William A. Wellman, Robert Carson
# 41    Norman Reilly Raine, Heinz Herald, Geza Herczeg
# 42                                      Spencer Tracy
# 43                                     Walter Brennan
# 44                                        Bette Davis
# 45                                        Fay Bainter
#
#                                film box_office
# 0                     The Scoundrel        NaN
# 1                      The Informer        NaN
# 2        The Story of Louis Pasteur        NaN
# 3                   Come and Get It        NaN
# 4                The Great Ziegfeld        NaN
# 5                   Anthony Adverse        NaN
# 6                         Dodsworth        NaN
# 7   The Charge of the Light Brigade        NaN
# 8                   Anthony Adverse        NaN
# 9                The Great Ziegfeld        NaN
# 10           Mr. Deeds Goes to Town     $8,362
# 11                  Anthony Adverse        NaN
# 12                  Anthony Adverse        NaN
# 13                       Swing Time        NaN
# 14               The Great Ziegfeld        NaN
# 15               The Country Cousin        NaN
# 16                  Give Me Liberty        NaN
# 17               Bored of Education        NaN
# 18                  The Public Pays        NaN
# 19                    San Francisco        NaN
# 20       The Story of Louis Pasteur        NaN
# 21       The Story of Louis Pasteur        NaN
# 22              Captains Courageous        NaN
# 23           The Life of Emile Zola        NaN
# 24                   The Good Earth        NaN
# 25                   In Old Chicago        NaN
# 26                     Lost Horizon        NaN
# 27                   In Old Chicago        NaN
# 28                   The Good Earth        NaN
# 29             A Damsel in Distress        NaN
# 30                  The Awful Truth        NaN
# 31                     Lost Horizon        NaN
# 32       One Hundred Men and a Girl        NaN
# 33                  Waikiki Wedding        NaN
# 34           The Life of Emile Zola        NaN
# 35                     The Old Mill        NaN
# 36                     Penny Wisdom        NaN
# 37  The Private Life of the Gannets        NaN
# 38                    Torture Money        NaN
# 39                    The Hurricane        NaN
# 40                   A Star Is Born        NaN
# 41           The Life of Emile Zola        NaN
# 42                        Boys Town        NaN
# 43                         Kentucky        NaN
# 44                          Jezebel        NaN
# 45                          Jezebel        NaN

# %%
df4 = movies[135:180]
df4 = df4.reset_index()
df4 = df4.drop('index', axis=1)
df4
# Out:
#     year_film  year_ceremony  ceremony                          category  \
# 0        1938           1939        11      ACTRESS IN A SUPPORTING ROLE
# 1        1938           1939        11                     ART DIRECTION
# 2        1938           1939        11                    CINEMATOGRAPHY
# 3        1938           1939        11                         DIRECTING
# 4        1938           1939        11                      FILM EDITING
# 5        1938           1939        11            MUSIC (Original Score)
# 6        1938           1939        11                   MUSIC (Scoring)
# 7        1938           1939        11                      MUSIC (Song)
# 8        1938           1939        11            OUTSTANDING PRODUCTION
# 9        1938           1939        11           SHORT SUBJECT (Cartoon)
# 10       1938           1939        11          SHORT SUBJECT (One-reel)
# 11       1938           1939        11          SHORT SUBJECT (Two-reel)
# 12       1938           1939        11                   SOUND RECORDING
# 13       1938           1939        11          WRITING (Original Story)
# 14       1938           1939        11              WRITING (Screenplay)
# 15       1939           1940        12                             ACTOR
# 16       1939           1940        12        ACTOR IN A SUPPORTING ROLE
# 17       1939           1940        12                           ACTRESS
# 18       1939           1940        12      ACTRESS IN A SUPPORTING ROLE
# 19       1939           1940        12                     ART DIRECTION
# 20       1939           1940        12  CINEMATOGRAPHY (Black-and-White)
# 21       1939           1940        12            CINEMATOGRAPHY (Color)
# 22       1939           1940        12                         DIRECTING
# 23       1939           1940        12                      FILM EDITING
# 24       1939           1940        12            MUSIC (Original Score)
# 25       1939           1940        12                   MUSIC (Scoring)
# 26       1939           1940        12                      MUSIC (Song)
# 27       1939           1940        12            OUTSTANDING PRODUCTION
# 28       1939           1940        12           SHORT SUBJECT (Cartoon)
# 29       1939           1940        12          SHORT SUBJECT (One-reel)
# 30       1939           1940        12          SHORT SUBJECT (Two-reel)
# 31       1939           1940        12                   SOUND RECORDING
# 32       1939           1940        12                   SPECIAL EFFECTS
# 33       1939           1940        12          WRITING (Original Story)
# 34       1939           1940        12              WRITING (Screenplay)
# 35       1940           1941        13                             ACTOR
# 36       1940           1941        13        ACTOR IN A SUPPORTING ROLE
# 37       1940           1941        13                           ACTRESS
# 38       1940           1941        13      ACTRESS IN A SUPPORTING ROLE
# 39       1940           1941        13   ART DIRECTION (Black-and-White)
# 40       1940           1941        13             ART DIRECTION (Color)
# 41       1940           1941        13  CINEMATOGRAPHY (Black-and-White)
# 42       1940           1941        13            CINEMATOGRAPHY (Color)
# 43       1940           1941        13                         DIRECTING
# 44       1940           1941        13                      FILM EDITING
#
#                                                  name  \
# 0                                         Fay Bainter
# 1                                        Carl J. Weyl
# 2                                   Joseph Ruttenberg
# 3                                         Frank Capra
# 4                                        Ralph Dawson
# 5                             Erich Wolfgang Korngold
# 6                                       Alfred Newman
# 7         Music by Ralph Rainger; Lyrics by Leo Robin
# 8                                            Columbia
# 9                               Walt Disney, Producer
# 10                                Metro-Goldwyn-Mayer
# 11                                       Warner Bros.
# 12  United Artists Studio Sound Department, Thomas...
# 13                      Dore Schary, Eleanore Griffin
# 14  Screenplay and Dialogue by George Bernard Shaw...
# 15                                       Robert Donat
# 16                                    Thomas Mitchell
# 17                                       Vivien Leigh
# 18                                    Hattie McDaniel
# 19                                       Lyle Wheeler
# 20                                       Gregg Toland
# 21                        Ernest Haller, Ray Rennahan
# 22                                     Victor Fleming
# 23                       Hal C. Kern, James E. Newcom
# 24                                   Herbert Stothart
# 25  Richard Hageman, Frank Harling, John Leipold, ...
# 26     Music by Harold Arlen; Lyrics by E. Y. Harburg
# 27                    Selznick International Pictures
# 28                              Walt Disney, Producer
# 29                                          Paramount
# 30                                       Warner Bros.
# 31  Universal Studio Sound Department, Bernard B. ...
# 32                          Fred Sersen, E. H. Hansen
# 33                                    Lewis R. Foster
# 34                                      Sidney Howard
# 35                                      James Stewart
# 36                                     Walter Brennan
# 37                                      Ginger Rogers
# 38                                       Jane Darwell
# 39                       Cedric Gibbons, Paul Groesse
# 40                                      Vincent Korda
# 41                                      George Barnes
# 42                                    Georges Périnal
# 43                                          John Ford
# 44                                      Anne Bauchens
#
#                             film  box_office
# 0                        Jezebel         NaN
# 1   The Adventures of Robin Hood         NaN
# 2                The Great Waltz         NaN
# 3     You Can't Take It with You         NaN
# 4   The Adventures of Robin Hood         NaN
# 5   The Adventures of Robin Hood         NaN
# 6       Alexander's Ragtime Band         NaN
# 7      The Big Broadcast of 1938         NaN
# 8     You Can't Take It with You         NaN
# 9             Ferdinand the Bull         NaN
# 10       That Mothers Might Live         NaN
# 11   Declaration of Independence         NaN
# 12       The Cowboy and the Lady         NaN
# 13                     Boys Town         NaN
# 14                     Pygmalion         NaN
# 15            Goodbye, Mr. Chips         NaN
# 16                    Stagecoach         NaN
# 17            Gone with the Wind         NaN
# 18            Gone with the Wind         NaN
# 19            Gone with the Wind         NaN
# 20             Wuthering Heights         NaN
# 21            Gone with the Wind         NaN
# 22            Gone with the Wind         NaN
# 23            Gone with the Wind         NaN
# 24              The Wizard of Oz         NaN
# 25                    Stagecoach         NaN
# 26              The Wizard of Oz         NaN
# 27            Gone with the Wind         NaN
# 28             The Ugly Duckling         NaN
# 29             Busy Little Bears         NaN
# 30               Sons of Liberty         NaN
# 31           When Tomorrow Comes         NaN
# 32                The Rains Came         NaN
# 33  Mr. Smith Goes to Washington         NaN
# 34            Gone with the Wind         NaN
# 35        The Philadelphia Story         NaN
# 36                 The Westerner         NaN
# 37                   Kitty Foyle         NaN
# 38           The Grapes of Wrath         NaN
# 39           Pride and Prejudice         NaN
# 40           The Thief of Bagdad         NaN
# 41                       Rebecca         NaN
# 42           The Thief of Bagdad         NaN
# 43           The Grapes of Wrath         NaN
# 44     North West Mounted Police         NaN

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

movies['box_office'] = np.nan

driver = webdriver.Firefox()

for index, (value, year) in enumerate(zip(df4['film'], df4['year_film'])):
    driver.get("https://www.google.com/webhp?hl=es&sa=X&ved=0ahUKEwib6NqMzP7_AhUbVqQEHU22BKcQPAgJ")
    driver.implicitly_wait(2)

    try:
        driver.find_element("css selector", "#L2AGLb > div:nth-child(1)").click()  # We click to accept the cookies
    except:
        pass

    driver.find_element("css selector", "#APjFqb").send_keys(f'"{value} {str(year)}" site:https://www.boxofficemojo.com/', Keys.ENTER)  # We select the search box with each film and year

    try:
        driver.find_element("css selector", ".LC20lb").click()  # If we get results, we click on the link

        try:
            box_office = driver.find_element('css selector', '.mojo-performance-summary-table > div:nth-child(4) > span:nth-child(3) > span:nth-child(1)').text  # If the page shows the box office, we store the value in a variable called 'box_office'
            df4.loc[index, 'box_office'] = box_office

        except:
            df4.loc[index, 'box_office'] = np.nan  # If not, we store the value as null
    except:
        df4.loc[index, 'box_office'] = np.nan

driver.quit()

# %%
df4
# Out:
#     year_film  year_ceremony  ceremony                          category  \
# 0        1938           1939        11      ACTRESS IN A SUPPORTING ROLE
# 1        1938           1939        11                     ART DIRECTION
# 2        1938           1939        11                    CINEMATOGRAPHY
# 3        1938           1939        11                         DIRECTING
# 4        1938           1939        11                      FILM EDITING
# 5        1938           1939        11            MUSIC (Original Score)
# 6        1938           1939        11                   MUSIC (Scoring)
# 7        1938           1939        11                      MUSIC (Song)
# 8        1938           1939        11            OUTSTANDING PRODUCTION
# 9        1938           1939        11           SHORT SUBJECT (Cartoon)
# 10       1938           1939        11          SHORT SUBJECT (One-reel)
# 11       1938           1939        11          SHORT SUBJECT (Two-reel)
# 12       1938           1939        11                   SOUND RECORDING
# 13       1938           1939        11          WRITING (Original Story)
# 14       1938           1939        11              WRITING (Screenplay)
# 15       1939           1940        12                             ACTOR
# 16       1939           1940        12        ACTOR IN A SUPPORTING ROLE
# 17       1939           1940        12                           ACTRESS
# 18       1939           1940        12      ACTRESS IN A SUPPORTING ROLE
# 19       1939           1940        12                     ART DIRECTION
# 20       1939           1940        12  CINEMATOGRAPHY (Black-and-White)
# 21       1939           1940        12            CINEMATOGRAPHY (Color)
# 22       1939           1940        12                         DIRECTING
# 23       1939           1940        12                      FILM EDITING
# 24       1939           1940        12            MUSIC (Original Score)
# 25       1939           1940        12                   MUSIC (Scoring)
# 26       1939           1940        12                      MUSIC (Song)
# 27       1939           1940        12            OUTSTANDING PRODUCTION
# 28       1939           1940        12           SHORT SUBJECT (Cartoon)
# 29       1939           1940        12          SHORT SUBJECT (One-reel)
# 30       1939           1940        12          SHORT SUBJECT (Two-reel)
# 31       1939           1940        12                   SOUND RECORDING
# 32       1939           1940        12                   SPECIAL EFFECTS
# 33       1939           1940        12          WRITING (Original Story)
# 34       1939           1940        12              WRITING (Screenplay)
# 35       1940           1941        13                             ACTOR
# 36       1940           1941        13        ACTOR IN A SUPPORTING ROLE
# 37       1940           1941        13                           ACTRESS
# 38       1940           1941        13      ACTRESS IN A SUPPORTING ROLE
# 39       1940           1941        13   ART DIRECTION (Black-and-White)
# 40       1940           1941        13             ART DIRECTION (Color)
# 41       1940           1941        13  CINEMATOGRAPHY (Black-and-White)
# 42       1940           1941        13            CINEMATOGRAPHY (Color)
# 43       1940           1941        13                         DIRECTING
# 44       1940           1941        13                      FILM EDITING
#
#                                                  name  \
# 0                                         Fay Bainter
# 1                                        Carl J. Weyl
# 2                                   Joseph Ruttenberg
# 3                                         Frank Capra
# 4                                        Ralph Dawson
# 5                             Erich Wolfgang Korngold
# 6                                       Alfred Newman
# 7         Music by Ralph Rainger; Lyrics by Leo Robin
# 8                                            Columbia
# 9                               Walt Disney, Producer
# 10                                Metro-Goldwyn-Mayer
# 11                                       Warner Bros.
# 12  United Artists Studio Sound Department, Thomas...
# 13                      Dore Schary, Eleanore Griffin
# 14  Screenplay and Dialogue by George Bernard Shaw...
# 15                                       Robert Donat
# 16                                    Thomas Mitchell
# 17                                       Vivien Leigh
# 18                                    Hattie McDaniel
# 19                                       Lyle Wheeler
# 20                                       Gregg Toland
# 21                        Ernest Haller, Ray Rennahan
# 22                                     Victor Fleming
# 23                       Hal C. Kern, James E. Newcom
# 24                                   Herbert Stothart
# 25  Richard Hageman, Frank Harling, John Leipold, ...
# 26     Music by Harold Arlen; Lyrics by E. Y. Harburg
# 27                    Selznick International Pictures
# 28                              Walt Disney, Producer
# 29                                          Paramount
# 30                                       Warner Bros.
# 31  Universal Studio Sound Department, Bernard B. ...
# 32                          Fred Sersen, E. H. Hansen
# 33                                    Lewis R. Foster
# 34                                      Sidney Howard
# 35                                      James Stewart
# 36                                     Walter Brennan
# 37                                      Ginger Rogers
# 38                                       Jane Darwell
# 39                       Cedric Gibbons, Paul Groesse
# 40                                      Vincent Korda
# 41                                      George Barnes
# 42                                    Georges Périnal
# 43                                          John Ford
# 44                                      Anne Bauchens
#
#                             film    box_office
# 0                        Jezebel           NaN
# 1   The Adventures of Robin Hood           NaN
# 2                The Great Waltz           NaN
# 3     You Can't Take It with You           NaN
# 4   The Adventures of Robin Hood           NaN
# 5   The Adventures of Robin Hood           NaN
# 6       Alexander's Ragtime Band           NaN
# 7      The Big Broadcast of 1938           NaN
# 8     You Can't Take It with You           NaN
# 9             Ferdinand the Bull           NaN
# 10       That Mothers Might Live           NaN
# 11   Declaration of Independence           NaN
# 12       The Cowboy and the Lady           NaN
# 13                     Boys Town           NaN
# 14                     Pygmalion           NaN
# 15            Goodbye, Mr. Chips           NaN
# 16                    Stagecoach           NaN
# 17            Gone with the Wind  $402,382,193
# 18            Gone with the Wind  $402,382,193
# 19            Gone with the Wind  $402,382,193
# 20             Wuthering Heights      $624,643
# 21            Gone with the Wind  $402,382,193
# 22            Gone with the Wind  $402,382,193
# 23            Gone with the Wind  $402,382,193
# 24              The Wizard of Oz   $25,637,669
# 25                    Stagecoach           NaN
# 26              The Wizard of Oz   $25,637,669
# 27            Gone with the Wind  $402,382,193
# 28             The Ugly Duckling           NaN
# 29             Busy Little Bears           NaN
# 30               Sons of Liberty           NaN
# 31           When Tomorrow Comes           NaN
# 32                The Rains Came           NaN
# 33  Mr. Smith Goes to Washington      $144,738
# 34            Gone with the Wind  $402,382,193
# 35        The Philadelphia Story      $411,663
# 36                 The Westerner   $76,411,819
# 37                   Kitty Foyle           NaN
# 38           The Grapes of Wrath           NaN
# 39           Pride and Prejudice           NaN
# 40           The Thief of Bagdad           NaN
# 41                       Rebecca       $72,275
# 42           The Thief of Bagdad           NaN
# 43           The Grapes of Wrath           NaN
# 44     North West Mounted Police           NaN
