# %%
import os

# Get the current working directory
current_directory = os.getcwd()

# Print the current working directory to know where my csv is
print(current_directory)
# Out:
# /Users/davidusuariocasa/Desktop/Projects/ETL_project

# %%
import pandas as pd

# %%
movies = pd.read_csv('/Users/davidusuariocasa/Desktop/oscars.csv') # I open the csv with the Oscar winners from 1928 to 2023

movies
# Out:
#        year_film  year_ceremony  ceremony                category  \
# 0           1927           1928         1                   ACTOR
# 1           1927           1928         1                   ACTOR
# 2           1927           1928         1                 ACTRESS
# 3           1927           1928         1                 ACTRESS
# 4           1927           1928         1                 ACTRESS
# ...          ...            ...       ...                     ...
# 10760       2022           2023        95          HONORARY AWARD
# 10761       2022           2023        95          HONORARY AWARD
# 10762       2022           2023        95          HONORARY AWARD
# 10763       2022           2023        95  GORDON E. SAWYER AWARD
# 10764       2022           2023        95   AWARD OF COMMENDATION
#
#                                                     name                 film  \
# 0                                    Richard Barthelmess            The Noose
# 1                                          Emil Jannings     The Last Command
# 2                                         Louise Dresser      A Ship Comes In
# 3                                           Janet Gaynor           7th Heaven
# 4                                         Gloria Swanson       Sadie Thompson
# ...                                                  ...                  ...
# 10760  To Euzhan Palcy, a masterful filmmaker who bro...                  NaN
# 10761  To Diane Warren, for her genius, generosity an...                  NaN
# 10762  To Peter Weir, a fearless and consummate filmm...                  NaN
# 10763                                          Iain Neil                  NaN
# 10764  To Ryan Laney for his innovative adaptation an...  Welcome to Chechnya
#
#        winner
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
# ...       ...
# 10760    True
# 10761    True
# 10762    True
# 10763    True
# 10764    True
#
# [10765 rows x 7 columns]

# %%
filtered_df = movies[movies['winner'] == True] # I filter by 'True' only to show the winners and discard the nominated who didn't win (those with value 'False')

filtered_df
# Out:
#        year_film  year_ceremony  ceremony                category  \
# 1           1927           1928         1                   ACTOR
# 3           1927           1928         1                 ACTRESS
# 6           1927           1928         1           ART DIRECTION
# 9           1927           1928         1          CINEMATOGRAPHY
# 10          1927           1928         1          CINEMATOGRAPHY
# ...          ...            ...       ...                     ...
# 10760       2022           2023        95          HONORARY AWARD
# 10761       2022           2023        95          HONORARY AWARD
# 10762       2022           2023        95          HONORARY AWARD
# 10763       2022           2023        95  GORDON E. SAWYER AWARD
# 10764       2022           2023        95   AWARD OF COMMENDATION
#
#                                                     name                 film  \
# 1                                          Emil Jannings     The Last Command
# 3                                           Janet Gaynor           7th Heaven
# 6                                William Cameron Menzies            The Dove;
# 9                                         Charles Rosher              Sunrise
# 10                                           Karl Struss              Sunrise
# ...                                                  ...                  ...
# 10760  To Euzhan Palcy, a masterful filmmaker who bro...                  NaN
# 10761  To Diane Warren, for her genius, generosity an...                  NaN
# 10762  To Peter Weir, a fearless and consummate filmm...                  NaN
# 10763                                          Iain Neil                  NaN
# 10764  To Ryan Laney for his innovative adaptation an...  Welcome to Chechnya
#
#        winner
# 1        True
# 3        True
# 6        True
# 9        True
# 10       True
# ...       ...
# 10760    True
# 10761    True
# 10762    True
# 10763    True
# 10764    True
#
# [2438 rows x 7 columns]

# %%
null_rows = filtered_df[movies.isnull().any(axis=1)] # I do this to see which rows contain null values

finaldf = filtered_df.dropna() # And now I drop all my null values

finaldf # now I have all the winners, without null values
# Out:
#        year_film  year_ceremony  ceremony                       category  \
# 1           1927           1928         1                          ACTOR
# 3           1927           1928         1                        ACTRESS
# 6           1927           1928         1                  ART DIRECTION
# 9           1927           1928         1                 CINEMATOGRAPHY
# 10          1927           1928         1                 CINEMATOGRAPHY
# ...          ...            ...       ...                            ...
# 10743       2022           2023        95                          SOUND
# 10745       2022           2023        95                 VISUAL EFFECTS
# 10753       2022           2023        95   WRITING (Adapted Screenplay)
# 10755       2022           2023        95  WRITING (Original Screenplay)
# 10764       2022           2023        95          AWARD OF COMMENDATION
#
#                                                     name  \
# 1                                          Emil Jannings
# 3                                           Janet Gaynor
# 6                                William Cameron Menzies
# 9                                         Charles Rosher
# 10                                           Karl Struss
# ...                                                  ...
# 10743  Mark Weingarten, James H. Mather, Al Nelson, C...
# 10745  Joe Letteri, Richard Baneham, Eric Saindon and...
# 10753                         Screenplay by Sarah Polley
# 10755          Written by Daniel Kwan & Daniel Scheinert
# 10764  To Ryan Laney for his innovative adaptation an...
#
#                                     film  winner
# 1                       The Last Command    True
# 3                             7th Heaven    True
# 6                              The Dove;    True
# 9                                Sunrise    True
# 10                               Sunrise    True
# ...                                  ...     ...
# 10743                  Top Gun: Maverick    True
# 10745           Avatar: The Way of Water    True
# 10753                      Women Talking    True
# 10755  Everything Everywhere All at Once    True
# 10764                Welcome to Chechnya    True
#
# [2149 rows x 7 columns]

# %%
finaldf.reset_index(inplace = True) # Now I reset all indexes in my df

finaldf
# Out:
#       index  year_film  year_ceremony  ceremony  \
# 0         1       1927           1928         1
# 1         3       1927           1928         1
# 2         6       1927           1928         1
# 3         9       1927           1928         1
# 4        10       1927           1928         1
# ...     ...        ...            ...       ...
# 2144  10743       2022           2023        95
# 2145  10745       2022           2023        95
# 2146  10753       2022           2023        95
# 2147  10755       2022           2023        95
# 2148  10764       2022           2023        95
#
#                            category  \
# 0                             ACTOR
# 1                           ACTRESS
# 2                     ART DIRECTION
# 3                    CINEMATOGRAPHY
# 4                    CINEMATOGRAPHY
# ...                             ...
# 2144                          SOUND
# 2145                 VISUAL EFFECTS
# 2146   WRITING (Adapted Screenplay)
# 2147  WRITING (Original Screenplay)
# 2148          AWARD OF COMMENDATION
#
#                                                    name  \
# 0                                         Emil Jannings
# 1                                          Janet Gaynor
# 2                               William Cameron Menzies
# 3                                        Charles Rosher
# 4                                           Karl Struss
# ...                                                 ...
# 2144  Mark Weingarten, James H. Mather, Al Nelson, C...
# 2145  Joe Letteri, Richard Baneham, Eric Saindon and...
# 2146                         Screenplay by Sarah Polley
# 2147          Written by Daniel Kwan & Daniel Scheinert
# 2148  To Ryan Laney for his innovative adaptation an...
#
#                                    film  winner
# 0                      The Last Command    True
# 1                            7th Heaven    True
# 2                             The Dove;    True
# 3                               Sunrise    True
# 4                               Sunrise    True
# ...                                 ...     ...
# 2144                  Top Gun: Maverick    True
# 2145           Avatar: The Way of Water    True
# 2146                      Women Talking    True
# 2147  Everything Everywhere All at Once    True
# 2148                Welcome to Chechnya    True
#
# [2149 rows x 8 columns]

# %%
columns_to_drop = ['winner', 'index'] # I create a list with the names of the columns I want to remove from my df

finaldf.drop(columns=columns_to_drop, inplace=True) # Now I remove the column 'winner' and 'index'

# %%
#selected_categories = ['OUTSTANDING PICTURE', 'UNIQUE AND ARTISTIC PICTURE', 'OUTSTANDING PRODUCTION', 'SHORT SUBJECT (Cartoon)', 'SHORT SUBJECT (Comedy)', 'SHORT SUBJECT (Novelty)', 'ASSISTANT DIRECTOR', 'MUSIC (Scoring)', 'MUSIC (Song)', 'DANCE DIRECTION', 'SHORT SUBJECT (Color)', 'SHORT SUBJECT (One-reel)', 'SHORT SUBJECT (Two-reel)', 'SPECIAL EFFECTS', 'DOCUMENTARY (Short Subject)', 'DOCUMENTARY (Feature)', 'FOREIGN LANGUAGE FILM', 'BEST PICTURE', 'SHORT FILM (Animated)', 'SHORT FILM (Live Action)', 'SHORT FILM (Dramatic Live Action)', 'ANIMATED FEATURE FILM', 'INTERNATIONAL FEATURE FILM', 'DOCUMENTARY FEATURE FILM', 'DOCUMENTARY SHORT FILM']

#finaldf = no_nulls[no_nulls['category'].isin(selected_categories)] # I select only those winning categories that I consider represent best the film itself

#finaldf.reset_index(inplace = True) # I reset the indexes

# %%
finaldf # This is my final df
# Out:
#       year_film  year_ceremony  ceremony                       category  \
# 0          1927           1928         1                          ACTOR
# 1          1927           1928         1                        ACTRESS
# 2          1927           1928         1                  ART DIRECTION
# 3          1927           1928         1                 CINEMATOGRAPHY
# 4          1927           1928         1                 CINEMATOGRAPHY
# ...         ...            ...       ...                            ...
# 2144       2022           2023        95                          SOUND
# 2145       2022           2023        95                 VISUAL EFFECTS
# 2146       2022           2023        95   WRITING (Adapted Screenplay)
# 2147       2022           2023        95  WRITING (Original Screenplay)
# 2148       2022           2023        95          AWARD OF COMMENDATION
#
#                                                    name  \
# 0                                         Emil Jannings
# 1                                          Janet Gaynor
# 2                               William Cameron Menzies
# 3                                        Charles Rosher
# 4                                           Karl Struss
# ...                                                 ...
# 2144  Mark Weingarten, James H. Mather, Al Nelson, C...
# 2145  Joe Letteri, Richard Baneham, Eric Saindon and...
# 2146                         Screenplay by Sarah Polley
# 2147          Written by Daniel Kwan & Daniel Scheinert
# 2148  To Ryan Laney for his innovative adaptation an...
#
#                                    film
# 0                      The Last Command
# 1                            7th Heaven
# 2                             The Dove;
# 3                               Sunrise
# 4                               Sunrise
# ...                                 ...
# 2144                  Top Gun: Maverick
# 2145           Avatar: The Way of Water
# 2146                      Women Talking
# 2147  Everything Everywhere All at Once
# 2148                Welcome to Chechnya
#
# [2149 rows x 6 columns]

# %%
finaldf.to_csv('finaldf.csv', index=False)

# %%
# Now to do our web scraping, we need to import all these libraries

import numpy as np 
from selenium import webdriver # webdriver permite manejar un navegador 
from webdriver_manager.chrome import ChromeDriverManager # permite instalar y mantener actualizado el driver de chrome
from selenium.webdriver.common.keys import Keys # permite simular teclas del teclado 
from selenium.webdriver.chrome.options import Options # permite configurar el driver de chrome como modo incognito o maximizar la ventana
import time # esperas entre ejecuciones de codigo
import random


import warnings # permite ignorar los warnings de python 
warnings.filterwarnings('ignore')

# %%
opciones= Options()
opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
#para ocultarme como robot
opciones.add_experimental_option('useAutomationExtension', False)
opciones.add_argument('--start-maximized') #empezar maximizado
opciones.add_argument('user.data-dir=selenium') #guarda las cookies
opciones.add_argument('--incognito')#incognito window

# %%
df1 = finaldf.iloc[:45]

# %%
df1
# Out:
#     index  year_film  year_ceremony  ceremony                      category  \
# 0       1       1927           1928         1                         ACTOR
# 1       3       1927           1928         1                       ACTRESS
# 2       6       1927           1928         1                 ART DIRECTION
# 3       9       1927           1928         1                CINEMATOGRAPHY
# 4      10       1927           1928         1                CINEMATOGRAPHY
# 5      11       1927           1928         1    DIRECTING (Comedy Picture)
# 6      13       1927           1928         1  DIRECTING (Dramatic Picture)
# 7      17       1927           1928         1           ENGINEERING EFFECTS
# 8      21       1927           1928         1           OUTSTANDING PICTURE
# 9      22       1927           1928         1   UNIQUE AND ARTISTIC PICTURE
# 10     27       1927           1928         1          WRITING (Adaptation)
# 11     29       1927           1928         1      WRITING (Original Story)
# 12     36       1928           1929         2                         ACTOR
# 13     45       1928           1929         2                       ACTRESS
# 14     47       1928           1929         2                 ART DIRECTION
# 15     52       1928           1929         2                CINEMATOGRAPHY
# 16     59       1928           1929         2                     DIRECTING
# 17     64       1928           1929         2           OUTSTANDING PICTURE
# 18     70       1928           1929         2                       WRITING
# 19     73       1929           1930         3                         ACTOR
# 20     82       1929           1930         3                       ACTRESS
# 21     86       1929           1930         3                 ART DIRECTION
# 22     94       1929           1930         3                CINEMATOGRAPHY
# 23     98       1929           1930         3                     DIRECTING
# 24    100       1929           1930         3        OUTSTANDING PRODUCTION
# 25    105       1929           1930         3               SOUND RECORDING
# 26    111       1929           1930         3                       WRITING
# 27    115       1930           1931         4                         ACTOR
# 28    121       1930           1931         4                       ACTRESS
# 29    125       1930           1931         4                 ART DIRECTION
# 30    134       1930           1931         4                CINEMATOGRAPHY
# 31    139       1930           1931         4                     DIRECTING
# 32    140       1930           1931         4        OUTSTANDING PRODUCTION
# 33    149       1930           1931         4          WRITING (Adaptation)
# 34    154       1930           1931         4      WRITING (Original Story)
# 35    159       1931           1932         5                         ACTOR
# 36    161       1931           1932         5                         ACTOR
# 37    164       1931           1932         5                       ACTRESS
# 38    167       1931           1932         5                 ART DIRECTION
# 39    170       1931           1932         5                CINEMATOGRAPHY
# 40    171       1931           1932         5                     DIRECTING
# 41    178       1931           1932         5        OUTSTANDING PRODUCTION
# 42    182       1931           1932         5       SHORT SUBJECT (Cartoon)
# 43    186       1931           1932         5        SHORT SUBJECT (Comedy)
# 44    191       1931           1932         5       SHORT SUBJECT (Novelty)
#
#                                                  name  \
# 0                                       Emil Jannings
# 1                                        Janet Gaynor
# 2                             William Cameron Menzies
# 3                                      Charles Rosher
# 4                                         Karl Struss
# 5                                     Lewis Milestone
# 6                                       Frank Borzage
# 7                                         Roy Pomeroy
# 8                              Paramount Famous Lasky
# 9                                                 Fox
# 10                                    Benjamin Glazer
# 11                                          Ben Hecht
# 12                                      Warner Baxter
# 13                                      Mary Pickford
# 14                                     Cedric Gibbons
# 15                                     Clyde De Vinna
# 16                                        Frank Lloyd
# 17                                Metro-Goldwyn-Mayer
# 18                                         Hans Kraly
# 19                                      George Arliss
# 20                                      Norma Shearer
# 21                                       Herman Rosse
# 22             Joseph T. Rucker, Willard Van Der Veer
# 23                                    Lewis Milestone
# 24                                          Universal
# 25  Metro-Goldwyn-Mayer Studio Sound Department, D...
# 26                                     Frances Marion
# 27                                   Lionel Barrymore
# 28                                     Marie Dressler
# 29                                            Max Rée
# 30                                       Floyd Crosby
# 31                                      Norman Taurog
# 32                                          RKO Radio
# 33                                   Howard Estabrook
# 34                                 John Monk Saunders
# 35                                      Wallace Beery
# 36                                      Fredric March
# 37                                        Helen Hayes
# 38                                       Gordon Wiles
# 39                                         Lee Garmes
# 40                                      Frank Borzage
# 41                                Metro-Goldwyn-Mayer
# 42                              Walt Disney, Producer
# 43                                Hal Roach, Producer
# 44                             Mack Sennett, Producer
#
#                                film
# 0                  The Last Command
# 1                        7th Heaven
# 2                         The Dove;
# 3                           Sunrise
# 4                           Sunrise
# 5               Two Arabian Knights
# 6                        7th Heaven
# 7                             Wings
# 8                             Wings
# 9                           Sunrise
# 10                       7th Heaven
# 11                       Underworld
# 12                   In Old Arizona
# 13                         Coquette
# 14       The Bridge of San Luis Rey
# 15  White Shadows in the South Seas
# 16                  The Divine Lady
# 17              The Broadway Melody
# 18                      The Patriot
# 19                         Disraeli
# 20                     The Divorcee
# 21                     King of Jazz
# 22      With Byrd at the South Pole
# 23   All Quiet on the Western Front
# 24   All Quiet on the Western Front
# 25                    The Big House
# 26                    The Big House
# 27                      A Free Soul
# 28                     Min and Bill
# 29                         Cimarron
# 30                             Tabu
# 31                           Skippy
# 32                         Cimarron
# 33                         Cimarron
# 34                  The Dawn Patrol
# 35                        The Champ
# 36          Dr. Jekyll and Mr. Hyde
# 37       The Sin of Madelon Claudet
# 38                    Transatlantic
# 39                 Shanghai Express
# 40                         Bad Girl
# 41                      Grand Hotel
# 42                Flowers and Trees
# 43                    The Music Box
# 44              Wrestling Swordfish

# %%
import numpy as np
import pandas as pd # SELENIUM PARA ESCRAPEAR POR CÓDIGOSSS !!!!
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

df1['box_office'] = np.nan

driver = webdriver.Firefox()

for index, (value, year) in enumerate(zip(df1['film'], df1['year_film'])):
    driver.get("https://www.google.com/webhp?hl=es&sa=X&ved=0ahUKEwib6NqMzP7_AhUbVqQEHU22BKcQPAgJ")
    driver.implicitly_wait(2)

    try:
        driver.find_element("css selector", "#L2AGLb > div:nth-child(1)").click()  # We click to accept the cookies
    except:
        pass

    driver.find_element("css selector", "#APjFqb").send_keys(f'"{value} {str(year)}" site:https://www.boxofficemojo.com/', Keys.ENTER)  # We select the search box with each film and year

    try:
        driver.find_element("css selector", ".LC20lb").click()  # If we get results, we click on the link

        try:
            box_office = driver.find_element('css selector', '.mojo-performance-summary-table > div:nth-child(4) > span:nth-child(3) > span:nth-child(1)').text  # If the page shows the box office, we store the value in a variable called 'box_office'
            df1.loc[index, 'box_office'] = box_office

        except:
            df1.loc[index, 'box_office'] = np.nan  # If not, we store the value as null
    except:
        df1.loc[index, 'box_office'] = np.nan

driver.quit()

# %%
df1
# Out:
#     index  year_film  year_ceremony  ceremony                      category  \
# 0       1       1927           1928         1                         ACTOR
# 1       3       1927           1928         1                       ACTRESS
# 2       6       1927           1928         1                 ART DIRECTION
# 3       9       1927           1928         1                CINEMATOGRAPHY
# 4      10       1927           1928         1                CINEMATOGRAPHY
# 5      11       1927           1928         1    DIRECTING (Comedy Picture)
# 6      13       1927           1928         1  DIRECTING (Dramatic Picture)
# 7      17       1927           1928         1           ENGINEERING EFFECTS
# 8      21       1927           1928         1           OUTSTANDING PICTURE
# 9      22       1927           1928         1   UNIQUE AND ARTISTIC PICTURE
# 10     27       1927           1928         1          WRITING (Adaptation)
# 11     29       1927           1928         1      WRITING (Original Story)
# 12     36       1928           1929         2                         ACTOR
# 13     45       1928           1929         2                       ACTRESS
# 14     47       1928           1929         2                 ART DIRECTION
# 15     52       1928           1929         2                CINEMATOGRAPHY
# 16     59       1928           1929         2                     DIRECTING
# 17     64       1928           1929         2           OUTSTANDING PICTURE
# 18     70       1928           1929         2                       WRITING
# 19     73       1929           1930         3                         ACTOR
# 20     82       1929           1930         3                       ACTRESS
# 21     86       1929           1930         3                 ART DIRECTION
# 22     94       1929           1930         3                CINEMATOGRAPHY
# 23     98       1929           1930         3                     DIRECTING
# 24    100       1929           1930         3        OUTSTANDING PRODUCTION
# 25    105       1929           1930         3               SOUND RECORDING
# 26    111       1929           1930         3                       WRITING
# 27    115       1930           1931         4                         ACTOR
# 28    121       1930           1931         4                       ACTRESS
# 29    125       1930           1931         4                 ART DIRECTION
# 30    134       1930           1931         4                CINEMATOGRAPHY
# 31    139       1930           1931         4                     DIRECTING
# 32    140       1930           1931         4        OUTSTANDING PRODUCTION
# 33    149       1930           1931         4          WRITING (Adaptation)
# 34    154       1930           1931         4      WRITING (Original Story)
# 35    159       1931           1932         5                         ACTOR
# 36    161       1931           1932         5                         ACTOR
# 37    164       1931           1932         5                       ACTRESS
# 38    167       1931           1932         5                 ART DIRECTION
# 39    170       1931           1932         5                CINEMATOGRAPHY
# 40    171       1931           1932         5                     DIRECTING
# 41    178       1931           1932         5        OUTSTANDING PRODUCTION
# 42    182       1931           1932         5       SHORT SUBJECT (Cartoon)
# 43    186       1931           1932         5        SHORT SUBJECT (Comedy)
# 44    191       1931           1932         5       SHORT SUBJECT (Novelty)
#
#                                                  name  \
# 0                                       Emil Jannings
# 1                                        Janet Gaynor
# 2                             William Cameron Menzies
# 3                                      Charles Rosher
# 4                                         Karl Struss
# 5                                     Lewis Milestone
# 6                                       Frank Borzage
# 7                                         Roy Pomeroy
# 8                              Paramount Famous Lasky
# 9                                                 Fox
# 10                                    Benjamin Glazer
# 11                                          Ben Hecht
# 12                                      Warner Baxter
# 13                                      Mary Pickford
# 14                                     Cedric Gibbons
# 15                                     Clyde De Vinna
# 16                                        Frank Lloyd
# 17                                Metro-Goldwyn-Mayer
# 18                                         Hans Kraly
# 19                                      George Arliss
# 20                                      Norma Shearer
# 21                                       Herman Rosse
# 22             Joseph T. Rucker, Willard Van Der Veer
# 23                                    Lewis Milestone
# 24                                          Universal
# 25  Metro-Goldwyn-Mayer Studio Sound Department, D...
# 26                                     Frances Marion
# 27                                   Lionel Barrymore
# 28                                     Marie Dressler
# 29                                            Max Rée
# 30                                       Floyd Crosby
# 31                                      Norman Taurog
# 32                                          RKO Radio
# 33                                   Howard Estabrook
# 34                                 John Monk Saunders
# 35                                      Wallace Beery
# 36                                      Fredric March
# 37                                        Helen Hayes
# 38                                       Gordon Wiles
# 39                                         Lee Garmes
# 40                                      Frank Borzage
# 41                                Metro-Goldwyn-Mayer
# 42                              Walt Disney, Producer
# 43                                Hal Roach, Producer
# 44                             Mack Sennett, Producer
#
#                                film box_office
# 0                  The Last Command        NaN
# 1                        7th Heaven        NaN
# 2                         The Dove;        NaN
# 3                           Sunrise   $121,107
# 4                           Sunrise   $121,107
# 5               Two Arabian Knights        NaN
# 6                        7th Heaven        NaN
# 7                             Wings       $746
# 8                             Wings       $746
# 9                           Sunrise   $121,107
# 10                       7th Heaven        NaN
# 11                       Underworld        NaN
# 12                   In Old Arizona        NaN
# 13                         Coquette        NaN
# 14       The Bridge of San Luis Rey        NaN
# 15  White Shadows in the South Seas        NaN
# 16                  The Divine Lady        NaN
# 17              The Broadway Melody        NaN
# 18                      The Patriot        NaN
# 19                         Disraeli        NaN
# 20                     The Divorcee        NaN
# 21                     King of Jazz        NaN
# 22      With Byrd at the South Pole        NaN
# 23   All Quiet on the Western Front        NaN
# 24   All Quiet on the Western Front        NaN
# 25                    The Big House        NaN
# 26                    The Big House        NaN
# 27                      A Free Soul        NaN
# 28                     Min and Bill        NaN
# 29                         Cimarron        NaN
# 30                             Tabu        NaN
# 31                           Skippy        NaN
# 32                         Cimarron        NaN
# 33                         Cimarron        NaN
# 34                  The Dawn Patrol        NaN
# 35                        The Champ        NaN
# 36          Dr. Jekyll and Mr. Hyde    $16,615
# 37       The Sin of Madelon Claudet        NaN
# 38                    Transatlantic        NaN
# 39                 Shanghai Express        NaN
# 40                         Bad Girl        NaN
# 41                      Grand Hotel        NaN
# 42                Flowers and Trees        NaN
# 43                    The Music Box        NaN
# 44              Wrestling Swordfish        NaN
